# %% [markdown]
# #  模型训练

# %%
# !python train.py --data_path=dataset/ --config_path=unet.yaml --output ./output
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
# ...

# %%
# !python train.py --data_path=dataset/ --config_path=unet.yaml --output ./output
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
# ...

# %%
# !python train.py --data_path=dataset/ --config_path=unet.yaml --output ./output
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
# ...

# %%
# !python train.py --data_path=dataset/ --config_path=unet.yaml
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
# ...

# %%
# !python train.py --data_path=dataset/ --config_path=unet.yaml --output ./output
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
# ...

# %% [markdown]
# # 模型测试

# %%
# !python eval.py --data_path=dataset/ --checkpoint_file_path=/cache/train/./checkpoint/./ckpt_0/best.ckpt --config_path=unet.yaml
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
# ...

# %%
# !python eval.py --data_path=testdata/ --checkpoint_file_path=./output/./checkpoint/./ckpt_0/best.ckpt --config_path=unet.yaml
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
# ...

# %%
# !python eval.py --data_path=testdata/ --checkpoint_file_path=./output/./checkpoint/./ckpt_0/best.ckpt --config_path=unet.yaml
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
# ...

# %% [markdown]
# # 模型导出

# %%
# !python export.py --config_path=./unet_export.yaml --file_name=unet --file_format=AIR
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 1,
#  'checkpoint_file_path': './output/./checkpoint/./ckpt_0/best.ckpt',
#  'checkpoint_path': './checkpoint/',
# ...

# %% [markdown]
# # Ascend310 推理

# %%
# !bash scripts/run_infer_310.sh unet unet.air 0
# Out:
# network:  unet
# mindir name: /home/ma-user/work/unet/unet.air
# device id:
# need preprocess or not:
# /home/ma-user/work/unet/scripts
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
# ...

# %%
# !cmake --version
# Out:
# cmake version 3.12.1
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %% [markdown]
# # 代码验证

# %%
import numpy as np
from mindspore import nn, Tensor

x = Tensor(np.array([[0.2, 0.5], [0.3, 0.1], [0.9, 0.6]]))
y = Tensor(np.array([[0, 1], [1, 0], [0, 1]]))
metric = nn.Dice(smooth=1e-5)
metric.clear()
metric.update(x, y)
dice = metric.eval()
print(dice)
# 0.20467791371802546
# Out:
# 0.2046779137180255

# %%
x
# Out:
# Tensor(shape=[3, 2], dtype=Float64, value=
# [[ 2.00000000e-01,  5.00000000e-01],
#  [ 3.00000000e-01,  1.00000000e-01],
#  [ 9.00000000e-01,  6.00000000e-01]])

# %% [markdown]
# ## 自定义metrics

# %%
import numpy as np
import mindspore
from mindspore import nn, Tensor
from mindspore.nn import Metric
# from mindspore.nn import rearrange_inputs

class MyMAE(Metric):

    def __init__(self):
        super(MyMAE, self).__init__()
        self.clear()

    def clear(self):
        """Clears the internal evaluation result."""
        self._abs_error_sum = 0
        self._samples_num = 0

#     @rearrange_inputs
    def update(self, *inputs):
        if len(inputs) != 2:
            raise ValueError('Mean absolute error need 2 inputs (y_pred, y), but got {}'.format(len(inputs)))
        y_pred = self._convert_data(inputs[0])
        y = self._convert_data(inputs[1])
        abs_error_sum = np.abs(y.reshape(y_pred.shape) - y_pred)
        self._abs_error_sum += abs_error_sum.sum()
        self._samples_num += y.shape[0]

    def eval(self):
        if self._samples_num == 0:
            raise RuntimeError('Total samples num must not be 0.')
        return self._abs_error_sum / self._samples_num


x = Tensor(np.array([[0.1, 0.2, 0.6, 0.9],[0.1, 0.2, 0.6, 0.9]]), mindspore.float32)
y = Tensor(np.array([[0.1, 0.25, 0.7, 0.9],[0.1, 0.25, 0.7, 0.9]]), mindspore.float32)
error = MyMAE()
error.clear()
error.update(x, y)
result = error.eval()
print(result)
# Out:
# 0.1499999612569809

# %%
def genConfusionMatrix(self, imgPredict, imgLabel):
    # remove classes from unlabeled pixels in gt image and predict
    mask = (imgLabel >= 0) & (imgLabel < self.numClass)
    label = self.numClass * imgLabel[mask] + imgPredict[mask]
    count = np.bincount(label, minlength=self.numClass**2)
    confusionMatrix = count.reshape(self.numClass, self.numClass)
    return confusionMatrix

def Frequency_Weighted_Intersection_over_Union(self):
    # FWIOU =     [(TP+FN)/(TP+FP+TN+FN)] *[TP / (TP + FP + FN)]
    freq = np.sum(self.confusion_matrix, axis=1) / np.sum(self.confusion_matrix)
    iu = np.diag(self.confusion_matrix) / (
            np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
            np.diag(self.confusion_matrix))
    FWIoU = (freq[freq > 0] * iu[freq > 0]).sum()
    return FWIoU

# %% [markdown]
# # 代码保存至GitHub

# %%
# !ssh-keygen -t rsa -C "2018605007@qq.com"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/home/ma-user/.ssh/id_rsa): ^C

# %%
# !ls /home/ma-user/.ssh/
# Out:
# known_hosts

# %%
# !git init
# Out:
# Initialized empty Git repository in /home/ma-user/work/unet/.git/

# %%
# !git add README_CN.md

# %%
# !git config --global user.email "2018605007@qq.com"
# !git config --global user.name "Tu-kun"

# %%
# !git commit -m "first commit"
# Out:
# [master (root-commit) 290edfb] first commit
#  1478 files changed, 18095 insertions(+)
#  create mode 100644 Dockerfile
#  create mode 100644 README.md
#  create mode 100644 analyze_fail_0.dat
#  create mode 100644 ascend310_infer/inc/utils.h
#  create mode 100644 ascend310_infer/src/.ipynb_checkpoints/build-checkpoint.log
#  create mode 100644 ascend310_infer/src/CMakeCache.txt
#  create mode 100644 ascend310_infer/src/CMakeFiles/cmake.check_cache
#  create mode 100644 ascend310_infer/src/CMakeLists.txt
#  create mode 100644 ascend310_infer/src/build.log
#  create mode 100644 ascend310_infer/src/build.sh
#  create mode 100644 ascend310_infer/src/main.cc
#  create mode 100644 ascend310_infer/src/utils.cc
#  create mode 100644 "ascend310\346\216\250\347\220\206.yaml"
#  create mode 100644 eval.py
#  create mode 100644 export.py
#  create mode 100644 infer/Dockerfile
#  create mode 100644 infer/convert/aipp_unet_simple_opencv.cfg
#  create mode 100644 infer/convert/convert.sh
# ...

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/Tu-kun/Cultivated_land_division.git

# %%
# !git push -u origin main
# Out:
# Username for 'https://github.com': ^C

# %%
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/Tu-kun/Cultivated_land_division.git
git push -u origin main

# %%
# !rm -rf .git

# %%
git init                            //初始化仓库
git add .                         //添加到本地暂存区   或用  git add   (文件name)
git commit -m "first commit"                     //提交到本地仓库
git remote add origin https://github.com/Tu-kun/Cultivated_land_division.git       //添加远程仓库 
git pull origin master                                 //把远程仓库master分支拉取到本地仓库master分支
git push -u origin master                           //把本地仓库的master分支推送到远程仓库master分支
passward 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
