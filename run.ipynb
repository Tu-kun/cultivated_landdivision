# %% [markdown]
# #  模型训练

# %%
# !python train.py --data_path=dataset/ --config_path=unet.yaml --output ./output
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 32,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
#  'color': [[0, 0, 0],
#            [255, 0, 0],
#            [0, 255, 0],
#            [0, 0, 255],
#            [0, 255, 255],
#            [255, 0, 255],
#            [255, 255, 255]],
#  'crop': 'None',
#  'cross_valid_ind': 5,
#  'data_path': '/cache/data',
#  'data_url': '',
#  'dataset': 'ISBI',
#  'device_target': 'Ascend',
#  'distribute_epochs': 1600,
#  'enable_modelarts': False,
#  'enable_profiling': False,
#  'epochs': 400,
#  'eval_activate': 'Softmax',
#  'eval_interval': 10,
#  'eval_metrics': 'FWIOU',
#  'eval_resize': False,
#  'eval_start_epoch': 1,
#  'file_format': 'AIR',
#  'file_name': 'unet',
#  'filter_weight': ['final1.weight',
#                    'final2.weight',
#                    'final3.weight',
#                    'final4.weight'],
#  'height': 572,
#  'image_size': [128, 128],
#  'include_background': True,
#  'keep_checkpoint_max': 10,
#  'load_path': '/cache/checkpoint_path/',
#  'loss_scale': 1024.0,
#  'lr': 0.001,
#  'model_name': 'unet_simple',
#  'multiclass': True,
#  'num_channels': 3,
#  'num_classes': 2,
#  'output_path': '/cache/train',
#  'patch_size': [128, 128],
#  'patch_stride': 64,
#  'repeat': 1,
#  'result_path': '',
#  'resume': False,
#  'resume_ckpt': './',
#  'rst_path': '/result_Files/',
#  'run_distribute': False,
#  'run_eval': True,
#  'save_best_ckpt': True,
#  'show_eval': False,
#  'train_url': '',
#  'transfer_training': False,
#  'use_bn': True,
#  'use_deconv': True,
#  'use_ds': False,
#  'weight_decay': 0.0005,
#  'width': 572}
# train_dataset length is: 499
# valid_dataset_size length is: 4000
# ============== Starting Training ==============
# [WARNING] SESSION(22466,fffe25ffb160,python):2021-10-09-01:30:56.834.948 [mindspore/ccsrc/backend/session/ascend_session.cc:1377] SelectKernel] There are 23 node/nodes used raise precision to selected the kernel!
# epoch:   1, avg loss:0.4695, total cost: 156.027 s, per step fps:102.341
# [WARNING] SESSION(22466,fffe25ffb160,python):2021-10-09-01:33:17.935.266 [mindspore/ccsrc/backend/session/ascend_session.cc:1377] SelectKernel] There are 10 node/nodes used raise precision to selected the kernel!
# epoch: 1, FWIOU: 0.37499673938535805
# update best result: 0.37499673938535805
# update best checkpoint at: ./output/./checkpoint/./ckpt_0/best.ckpt
# epoch:   2, avg loss:0.4440, total cost: 51.025 s, per step fps:312.947
# epoch:   3, avg loss:0.4625, total cost: 67.759 s, per step fps:235.657
# epoch:   4, avg loss:0.4484, total cost: 66.763 s, per step fps:239.174
# epoch:   5, avg loss:0.3959, total cost: 70.229 s, per step fps:227.369
# epoch:   6, avg loss:0.3826, total cost: 68.435 s, per step fps:233.330
# epoch:   7, avg loss:0.4202, total cost: 67.759 s, per step fps:235.659
# epoch:   8, avg loss:0.3962, total cost: 68.010 s, per step fps:234.789
# epoch:   9, avg loss:0.3909, total cost: 67.777 s, per step fps:235.597
# epoch:  10, avg loss:0.4584, total cost: 70.313 s, per step fps:227.098
# epoch:  11, avg loss:0.3492, total cost: 73.666 s, per step fps:216.761
# epoch: 11, FWIOU: 0.3927246349090121
# update best result: 0.3927246349090121
# update best checkpoint at: ./output/./checkpoint/./ckpt_0/best.ckpt
# epoch:  12, avg loss:0.3884, total cost: 50.161 s, per step fps:318.337
# epoch:  13, avg loss:0.4151, total cost: 68.099 s, per step fps:234.483
# epoch:  14, avg loss:0.3974, total cost: 68.311 s, per step fps:233.754
# epoch:  15, avg loss:0.3510, total cost: 67.627 s, per step fps:236.117
# epoch:  16, avg loss:0.3759, total cost: 68.737 s, per step fps:232.306
# epoch:  17, avg loss:0.4359, total cost: 67.996 s, per step fps:234.838
# epoch:  18, avg loss:0.2980, total cost: 67.532 s, per step fps:236.453
# epoch:  19, avg loss:0.3914, total cost: 67.831 s, per step fps:235.409
# epoch:  20, avg loss:0.3491, total cost: 70.002 s, per step fps:228.109
# epoch:  21, avg loss:0.3724, total cost: 69.886 s, per step fps:228.487
# epoch: 21, FWIOU: 0.3933861793401105
# update best result: 0.3933861793401105
# update best checkpoint at: ./output/./checkpoint/./ckpt_0/best.ckpt
# epoch:  22, avg loss:0.3449, total cost: 51.939 s, per step fps:307.437
# epoch:  23, avg loss:0.3995, total cost: 68.347 s, per step fps:233.633
# epoch:  24, avg loss:0.3719, total cost: 67.685 s, per step fps:235.915
# epoch:  25, avg loss:0.3996, total cost: 70.398 s, per step fps:226.824
# epoch:  26, avg loss:0.3997, total cost: 68.367 s, per step fps:233.563
# epoch:  27, avg loss:0.3581, total cost: 69.582 s, per step fps:229.485
# epoch:  28, avg loss:0.4285, total cost: 68.248 s, per step fps:233.971
# epoch:  29, avg loss:0.3279, total cost: 68.849 s, per step fps:231.929
# epoch:  30, avg loss:0.4142, total cost: 69.243 s, per step fps:230.609
# epoch:  31, avg loss:0.3169, total cost: 80.377 s, per step fps:198.665
# epoch: 31, FWIOU: 0.3701478495536837
# epoch:  32, avg loss:0.4096, total cost: 63.903 s, per step fps:249.878
# epoch:  33, avg loss:0.3431, total cost: 85.006 s, per step fps:187.845
# epoch:  34, avg loss:0.4110, total cost: 86.044 s, per step fps:185.580
# epoch:  35, avg loss:0.3674, total cost: 84.326 s, per step fps:189.361
# epoch:  36, avg loss:0.4275, total cost: 84.160 s, per step fps:189.734
# epoch:  37, avg loss:0.4107, total cost: 75.646 s, per step fps:211.088
# epoch:  38, avg loss:0.4260, total cost: 68.850 s, per step fps:231.925
# epoch:  39, avg loss:0.3368, total cost: 68.922 s, per step fps:231.682
# epoch:  40, avg loss:0.3441, total cost: 68.244 s, per step fps:233.983
# epoch:  41, avg loss:0.3523, total cost: 69.053 s, per step fps:231.241
# epoch: 41, FWIOU: 0.3947966410953994
# update best result: 0.3947966410953994
# update best checkpoint at: ./output/./checkpoint/./ckpt_0/best.ckpt
# epoch:  42, avg loss:0.3458, total cost: 50.468 s, per step fps:316.401
# epoch:  43, avg loss:0.3689, total cost: 69.155 s, per step fps:230.902
# epoch:  44, avg loss:0.3608, total cost: 68.997 s, per step fps:231.430
# epoch:  45, avg loss:0.4186, total cost: 68.682 s, per step fps:232.492
# epoch:  46, avg loss:0.4532, total cost: 69.105 s, per step fps:231.069
# epoch:  47, avg loss:0.4261, total cost: 69.054 s, per step fps:231.240
# epoch:  48, avg loss:0.3956, total cost: 68.596 s, per step fps:232.784
# epoch:  49, avg loss:0.4016, total cost: 69.370 s, per step fps:230.187
# epoch:  50, avg loss:0.3417, total cost: 68.608 s, per step fps:232.743
# epoch:  51, avg loss:0.4526, total cost: 69.020 s, per step fps:231.353
# epoch: 51, FWIOU: 0.39740261234185176
# update best result: 0.39740261234185176
# update best checkpoint at: ./output/./checkpoint/./ckpt_0/best.ckpt
# epoch:  52, avg loss:0.3467, total cost: 50.247 s, per step fps:317.788
# epoch:  53, avg loss:0.4943, total cost: 67.399 s, per step fps:236.919
# epoch:  54, avg loss:0.3968, total cost: 68.026 s, per step fps:234.734
# epoch:  55, avg loss:0.4289, total cost: 67.710 s, per step fps:235.829
# epoch:  56, avg loss:0.4016, total cost: 67.951 s, per step fps:234.993
# epoch:  57, avg loss:0.3416, total cost: 68.158 s, per step fps:234.280
# epoch:  58, avg loss:0.3656, total cost: 69.531 s, per step fps:229.654
# epoch:  59, avg loss:0.3820, total cost: 68.534 s, per step fps:232.993
# epoch:  60, avg loss:0.3741, total cost: 69.293 s, per step fps:230.441
# epoch:  61, avg loss:0.3496, total cost: 71.078 s, per step fps:224.655
# epoch: 61, FWIOU: 0.3958803340218551
# epoch:  62, avg loss:0.4330, total cost: 50.979 s, per step fps:313.230
# epoch:  63, avg loss:0.3712, total cost: 71.731 s, per step fps:222.610
# epoch:  64, avg loss:0.3654, total cost: 70.491 s, per step fps:226.527
# epoch:  65, avg loss:0.3910, total cost: 69.172 s, per step fps:230.844
# epoch:  66, avg loss:0.4616, total cost: 67.737 s, per step fps:235.734
# epoch:  67, avg loss:0.3731, total cost: 67.515 s, per step fps:236.509
# epoch:  68, avg loss:0.4183, total cost: 76.426 s, per step fps:208.934
# epoch:  69, avg loss:0.3931, total cost: 82.649 s, per step fps:193.203
# epoch:  70, avg loss:0.4011, total cost: 84.729 s, per step fps:188.460
# epoch:  71, avg loss:0.3855, total cost: 81.253 s, per step fps:196.522
# epoch: 71, FWIOU: 0.3965786002788037
# epoch:  72, avg loss:0.4194, total cost: 61.202 s, per step fps:260.908
# epoch:  73, avg loss:0.3658, total cost: 81.047 s, per step fps:197.022
# epoch:  74, avg loss:0.3719, total cost: 67.704 s, per step fps:235.851
# epoch:  75, avg loss:0.3760, total cost: 68.263 s, per step fps:233.920
# epoch:  76, avg loss:0.3972, total cost: 69.033 s, per step fps:231.311
# epoch:  77, avg loss:0.3898, total cost: 69.264 s, per step fps:230.539
# epoch:  78, avg loss:0.4009, total cost: 68.140 s, per step fps:234.341
# epoch:  79, avg loss:0.3819, total cost: 68.709 s, per step fps:232.401
# epoch:  80, avg loss:0.3762, total cost: 68.689 s, per step fps:232.467
# epoch:  81, avg loss:0.3597, total cost: 69.320 s, per step fps:230.351
# epoch: 81, FWIOU: 0.39406708627756526
# epoch:  82, avg loss:0.4007, total cost: 50.542 s, per step fps:315.937
# epoch:  83, avg loss:0.4195, total cost: 67.872 s, per step fps:235.267
# epoch:  84, avg loss:0.3160, total cost: 68.316 s, per step fps:233.738
# epoch:  85, avg loss:0.4096, total cost: 67.760 s, per step fps:235.655
# epoch:  86, avg loss:0.4147, total cost: 68.072 s, per step fps:234.575
# epoch:  87, avg loss:0.4213, total cost: 67.479 s, per step fps:236.635
# epoch:  88, avg loss:0.4209, total cost: 67.189 s, per step fps:237.659
# epoch:  89, avg loss:0.3947, total cost: 67.604 s, per step fps:236.198
# epoch:  90, avg loss:0.3229, total cost: 68.450 s, per step fps:233.279
# epoch:  91, avg loss:0.3341, total cost: 66.797 s, per step fps:239.054
# epoch: 91, FWIOU: 0.39914528041916464
# update best result: 0.39914528041916464
# update best checkpoint at: ./output/./checkpoint/./ckpt_0/best.ckpt
# epoch:  92, avg loss:0.4238, total cost: 50.010 s, per step fps:319.297
# epoch:  93, avg loss:0.4779, total cost: 67.709 s, per step fps:235.834
# epoch:  94, avg loss:0.3882, total cost: 68.703 s, per step fps:232.419
# epoch:  95, avg loss:0.3761, total cost: 68.403 s, per step fps:233.439
# epoch:  96, avg loss:0.3954, total cost: 67.480 s, per step fps:236.632
# epoch:  97, avg loss:0.4228, total cost: 67.709 s, per step fps:235.834
# epoch:  98, avg loss:0.3569, total cost: 68.592 s, per step fps:232.798
# epoch:  99, avg loss:0.3740, total cost: 67.906 s, per step fps:235.148
# epoch: 100, avg loss:0.4717, total cost: 67.415 s, per step fps:236.862
# epoch: 101, avg loss:0.3678, total cost: 68.579 s, per step fps:232.843
# epoch: 101, FWIOU: 0.3958194203233261
# epoch: 102, avg loss:0.3159, total cost: 51.124 s, per step fps:312.337
# epoch: 103, avg loss:0.3905, total cost: 68.298 s, per step fps:233.800
# epoch: 104, avg loss:0.3867, total cost: 67.945 s, per step fps:235.015
# epoch: 105, avg loss:0.4253, total cost: 67.992 s, per step fps:234.852
# epoch: 106, avg loss:0.3355, total cost: 68.464 s, per step fps:233.232
# epoch: 107, avg loss:0.4537, total cost: 68.397 s, per step fps:233.459
# epoch: 108, avg loss:0.4137, total cost: 69.254 s, per step fps:230.571
# epoch: 109, avg loss:0.3191, total cost: 68.695 s, per step fps:232.447
# epoch: 110, avg loss:0.4143, total cost: 68.910 s, per step fps:231.721
# epoch: 111, avg loss:0.4006, total cost: 68.776 s, per step fps:232.173
# epoch: 111, FWIOU: 0.396183272255512
# ^C
# [WARNING] DEVICE(22466,ffffb5400e60,python):2021-10-09-03:44:07.269.654 [mindspore/ccsrc/runtime/device/ascend/signal_util.cc:51] IntHandler] Process 22466 receive KeyboardInterrupt signal.
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-14:
# Traceback (most recent call last):
#   File "/home/ma-user/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ma-user/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ma-user/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ma-user/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ma-user/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/ma-user/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()

# %% [markdown]
# # 模型测试

# %%
# !python eval.py --data_path=testdata/ --checkpoint_file_path=./output/./checkpoint/./ckpt_0/best.ckpt --config_path=unet.yaml
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 32,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
#  'color': [[0, 0, 0],
#            [255, 0, 0],
#            [0, 255, 0],
#            [0, 0, 255],
#            [0, 255, 255],
#            [255, 0, 255],
#            [255, 255, 255]],
#  'crop': 'None',
#  'cross_valid_ind': 5,
#  'data_path': '/cache/data',
#  'data_url': '',
#  'dataset': 'ISBI',
#  'device_target': 'Ascend',
#  'distribute_epochs': 1600,
#  'enable_modelarts': False,
#  'enable_profiling': False,
#  'epochs': 400,
#  'eval_activate': 'Softmax',
#  'eval_interval': 10,
#  'eval_metrics': 'FWIOU',
#  'eval_resize': False,
#  'eval_start_epoch': 1,
#  'file_format': 'AIR',
#  'file_name': 'unet',
#  'filter_weight': ['final1.weight',
#                    'final2.weight',
#                    'final3.weight',
#                    'final4.weight'],
#  'height': 572,
#  'image_size': [128, 128],
#  'include_background': True,
#  'keep_checkpoint_max': 10,
#  'load_path': '/cache/checkpoint_path/',
#  'loss_scale': 1024.0,
#  'lr': 0.001,
#  'model_name': 'unet_simple',
#  'multiclass': True,
#  'num_channels': 3,
#  'num_classes': 2,
#  'output_path': '/cache/train',
#  'patch_size': [128, 128],
#  'patch_stride': 64,
#  'repeat': 1,
#  'result_path': '',
#  'resume': False,
#  'resume_ckpt': './',
#  'rst_path': '/result_Files/',
#  'run_distribute': False,
#  'run_eval': True,
#  'save_best_ckpt': True,
#  'show_eval': False,
#  'train_url': '',
#  'transfer_training': False,
#  'use_bn': True,
#  'use_deconv': True,
#  'use_ds': False,
#  'weight_decay': 0.0005,
#  'width': 572}
# testdata/
# [WARNING] ME(58963:281473154682464,MainProcess):2021-10-09-03:44:48.837.756 [mindspore/train/serialization.py:581] Remove parameter prefix name: net., continue to load.
# ============== Starting Evaluating ============
# [WARNING] SESSION(58963,fffe85ffb160,python):2021-10-09-03:45:00.759.624 [mindspore/ccsrc/backend/session/ascend_session.cc:1381] SelectKernel] There are 27 node/nodes used reduce precision to selected the kernel!
# single fwiou is: 0.4343568054987974, IOU is: 0.8687136109975948
# single fwiou is: 0.3759211729034445, IOU is: 0.751842345806889
# single fwiou is: 0.4466007358704163, IOU is: 0.8932014717408326
# single fwiou is: 0.4280329685486197, IOU is: 0.8560659370972394
# ============== Cross valid FWIou is: 0.4212279207053195
# ============== Cross valid IOU is: 0.842455841410639

# %%
# !python eval.py --data_path=testdata/ --checkpoint_file_path=./output/./checkpoint/./ckpt_0/best.ckpt --config_path=unet.yaml
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 16,
#  'checkpoint_file_path': 'ckpt_unet_nested_adam-4-75.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
#  'color': [[0, 0, 0],
#            [255, 0, 0],
#            [0, 255, 0],
#            [0, 0, 255],
#            [0, 255, 255],
#            [255, 0, 255],
#            [255, 255, 255]],
#  'crop': 'None',
#  'cross_valid_ind': 1,
#  'data_path': '/cache/data',
#  'data_url': '',
#  'dataset': 'ISBI',
#  'device_target': 'Ascend',
#  'distribute_epochs': 1600,
#  'enable_modelarts': False,
#  'enable_profiling': False,
#  'epochs': 400,
#  'eval_activate': 'Softmax',
#  'eval_interval': 10,
#  'eval_metrics': 'FWIOU',
#  'eval_resize': False,
#  'eval_start_epoch': 1,
#  'file_format': 'AIR',
#  'file_name': 'unet',
#  'filter_weight': ['final1.weight',
#                    'final2.weight',
#                    'final3.weight',
#                    'final4.weight'],
#  'height': 572,
#  'image_size': [256, 256],
#  'include_background': True,
#  'keep_checkpoint_max': 10,
#  'load_path': '/cache/checkpoint_path/',
#  'loss_scale': 1024.0,
#  'lr': 0.001,
#  'model_name': 'unet_nested',
#  'multiclass': True,
#  'num_channels': 3,
#  'num_classes': 2,
#  'output_path': '/cache/train',
#  'patch_size': [256, 256],
#  'patch_stride': 128,
#  'repeat': 1,
#  'result_path': '',
#  'resume': False,
#  'resume_ckpt': './',
#  'rst_path': '/result_Files/',
#  'run_distribute': False,
#  'run_eval': True,
#  'save_best_ckpt': True,
#  'show_eval': False,
#  'train_url': '',
#  'transfer_training': False,
#  'use_bn': True,
#  'use_deconv': True,
#  'use_ds': True,
#  'weight_decay': 0.0005,
#  'width': 572}
# testdata/
# [WARNING] ME(1805:281473166397024,MainProcess):2021-10-05-01:23:04.254.641 [mindspore/train/serialization.py:581] Remove parameter prefix name: net., continue to load.
# ============== Starting Evaluating ============
# [WARNING] SESSION(1805,fffed8833160,python):2021-10-05-01:23:18.040.268 [mindspore/ccsrc/backend/session/ascend_session.cc:1381] SelectKernel] There are 45 node/nodes used reduce precision to selected the kernel!
# single fwiou is: 0.45448911588918384, IOU is: 0.9089782317783677
# single fwiou is: 0.3819997647001299, IOU is: 0.7639995294002598
# single fwiou is: 0.45554098147758976, IOU is: 0.9110819629551795
# single fwiou is: 0.42778651949475743, IOU is: 0.8555730389895149
# ============== Cross valid FWIou is: 0.42995409539041524
# ============== Cross valid IOU is: 0.8599081907808305

# %% [markdown]
# # 模型导出

# %%
# !python export.py --config_path=./unet_export.yaml --file_name=unet --file_format=AIR
# Out:
# {'enable_modelarts': 'Whether training on modelarts, default: False', 'data_url': 'Dataset url for obs', 'train_url': 'Training output url for obs', 'checkpoint_url': 'The location of checkpoint for obs', 'data_path': 'Dataset path for local', 'output_path': 'Training output path for local', 'load_path': 'The location of checkpoint for obs', 'device_target': 'Target device type, available: [Ascend, GPU, CPU]', 'enable_profiling': 'Whether enable profiling while training, default: False', 'num_classes': 'Class for dataset', 'batch_size': 'Batch size for training and evaluation', 'weight_decay': 'Weight decay.', 'keep_checkpoint_max': 'keep the last keep_checkpoint_max checkpoint', 'checkpoint_path': 'The location of the checkpoint file.', 'checkpoint_file_path': 'The location of the checkpoint file.'}
# {'FixedLossScaleManager': 1024.0,
#  'batch_size': 1,
#  'checkpoint_file_path': './output/./checkpoint/./ckpt_0/best.ckpt',
#  'checkpoint_path': './checkpoint/',
#  'checkpoint_url': '',
#  'color': [[0, 0, 0],
#            [255, 0, 0],
#            [0, 255, 0],
#            [0, 0, 255],
#            [0, 255, 255],
#            [255, 0, 255],
#            [255, 255, 255]],
#  'crop': 'None',
#  'cross_valid_ind': 1,
#  'data_path': '/cache/data',
#  'data_url': '',
#  'dataset': 'ISBI',
#  'device_target': 'Ascend',
#  'distribute_epochs': 1600,
#  'enable_modelarts': False,
#  'enable_profiling': False,
#  'epochs': 400,
#  'eval_activate': 'Softmax',
#  'eval_interval': 10,
#  'eval_metrics': 'dice_coeff',
#  'eval_resize': False,
#  'eval_start_epoch': 1,
#  'file_format': 'AIR',
#  'file_name': 'unet',
#  'filter_weight': ['final1.weight',
#                    'final2.weight',
#                    'final3.weight',
#                    'final4.weight'],
#  'height': 256,
#  'image_size': [256, 256],
#  'include_background': True,
#  'keep_checkpoint_max': 10,
#  'load_path': '/cache/checkpoint_path/',
#  'loss_scale': 1024.0,
#  'lr': 0.001,
#  'model_name': 'unet_nested',
#  'multiclass': True,
#  'num_channels': 3,
#  'num_classes': 2,
#  'output_path': '/cache/train',
#  'patch_size': [256, 256],
#  'patch_stride': 128,
#  'repeat': 1,
#  'result_path': '',
#  'resume': False,
#  'resume_ckpt': './',
#  'rst_path': '/result_Files/',
#  'run_distribute': False,
#  'run_eval': True,
#  'save_best_ckpt': True,
#  'show_eval': False,
#  'train_url': '',
#  'transfer_training': False,
#  'use_bn': True,
#  'use_deconv': True,
#  'use_ds': True,
#  'weight_decay': 0.0005,
#  'width': 256}
# [WARNING] ME(3163:281472878370400,MainProcess):2021-10-05-01:24:47.266.230 [mindspore/train/serialization.py:581] Remove parameter prefix name: net., continue to load.
# input_data: (1, 3, 256, 256)
# [WARNING] GE_ADPT(3163,ffff82edde60,python):2021-10-05-01:24:49.682.977 [mindspore/ccsrc/transform/graph_ir/convert.cc:333] InitParamWithData] net.final1.weight is not in params, and create a new node.
# [WARNING] GE_ADPT(3163,ffff82edde60,python):2021-10-05-01:24:49.683.644 [mindspore/ccsrc/transform/graph_ir/convert.cc:333] InitParamWithData] net.final2.weight is not in params, and create a new node.
# [WARNING] GE_ADPT(3163,ffff82edde60,python):2021-10-05-01:24:49.684.017 [mindspore/ccsrc/transform/graph_ir/convert.cc:333] InitParamWithData] net.final3.weight is not in params, and create a new node.
# [WARNING] GE_ADPT(3163,ffff82edde60,python):2021-10-05-01:24:49.742.481 [mindspore/ccsrc/transform/graph_ir/convert.cc:278] SetupParamInitSubGraph] Init parameter net.final1.weight didn't appear in graph.
# [WARNING] GE_ADPT(3163,ffff82edde60,python):2021-10-05-01:24:49.742.530 [mindspore/ccsrc/transform/graph_ir/convert.cc:278] SetupParamInitSubGraph] Init parameter net.final2.weight didn't appear in graph.
# [WARNING] GE_ADPT(3163,ffff82edde60,python):2021-10-05-01:24:49.742.544 [mindspore/ccsrc/transform/graph_ir/convert.cc:278] SetupParamInitSubGraph] Init parameter net.final3.weight didn't appear in graph.

# %% [markdown]
# # 代码保存至GitHub
